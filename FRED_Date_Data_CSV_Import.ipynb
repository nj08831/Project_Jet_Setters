# %%
# %matplotlib notebook

# %%
# This code will parse a two column [Date / Data] CSV file from FRED by Defined Period

# Import Dependencies
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt

# %%
# load CSV File

# loop_trigger = 'y'

# while loop trigger == 'y':

# File name: FRED_Query_Seattle_Rents.csv
file_df = input("Please enter file to load: ")

# Read CSV File and store into Pandas data frame
rent_data = pd.read_csv(file_df)
# Out:
# Please enter file to load: FRED_Query_Seattle_Rents.csv

# %%
# Append Formatted CSV
formatted_file_df = input("Please enter formatted file to load: ")

# Read CSV File and store into Pandas data frame
rent_data_formatted = pd.read_csv(formatted_file_df)
# Out:
# Please enter formatted file to load: CSV_Test_2.csv

# %%
# Development Purposes Only - Check Row Count
formatted_row_count = len(rent_data_formatted)
# rent_data_formatted.set_index('Date')
# rent_data_formatted_bin = pd.cut(rent_data_formatted['Index'].astype(float),1)
# formatted_series = pd.Series(rent_data_formatted.iloc[0:formatted_row_count,1])


print(formatted_row_count)
# Out:
# 227

# %%
# print(formatted_series)

rent_data_formatted.head()
# Out:
#          Date  Seattle Index  National Index
# 0  2000-01-01          205.9           181.1
# 1  2000-02-01          206.2           181.5
# 2  2000-03-01          206.8           182.0
# 3  2000-04-01          208.0           182.3
# 4  2000-05-01          209.2           182.7

# %%
print(rent_data_formatted.iloc[0:formatted_row_count,1])
# Out:
# 0      205.900
# 1      206.200
# 2      206.800
# 3      208.000
# 4      209.200
# 5      210.600
# 6      210.700
# 7      211.000
# 8      211.800
# 9      212.000
# 10     212.300
# 11     212.900
# 12     214.000
# 13     215.000
# 14     215.400
# 15     216.900
# 16     217.800
# 17     218.300
# 18     219.300
# 19     221.600
# 20     222.500
# 21     223.300
# 22     224.000
# 23     224.200
# 24     224.900
# 25     224.500
# 26     224.500
# 27     224.300
# 28     225.100
# 29     225.500
#         ...
# 197    337.863
# 198    340.090
# 199    341.520
# 200    342.992
# 201    344.750
# 202    346.538
# 203    348.636
# 204    350.553
# 205    352.477
# 206    353.852
# 207    354.830
# 208    356.837
# 209    358.338
# 210    359.928
# 211    361.934
# 212    364.532
# 213    367.334
# 214    369.700
# 215    371.517
# 216    372.752
# 217    374.179
# 218    375.461
# 219    376.431
# 220    377.963
# 221    381.577
# 222    383.584
# 223    385.998
# 224    388.246
# 225    389.370
# 226    390.636
# Name: Seattle Index, Length: 227, dtype: float64

# %%
# Display CSV
rent_data.head(10)
# Out:
#          DATE CUURA423SEHC01
# 0  1982-11-01        100.000
# 1  1982-12-01              .
# 2  1983-01-01        100.000
# 3  1983-02-01              .
# 4  1983-03-01         99.700
# 5  1983-04-01              .
# 6  1983-05-01         99.800
# 7  1983-06-01              .
# 8  1983-07-01        103.000
# 9  1983-08-01              .

# %%
# Date dependency calculation - Start Date
print(rent_data.iloc[0,0])
# Out:
# 1982-11-01

# %%
# Development Purposes Only - Show Type of Data In CSV
type(rent_data.iloc[0,0])
# Out:
# str

# %%
# Convert dataseries to years/months as Integers
csv_year = int(rent_data.iloc[0,0][0:4])
csv_month = int(rent_data.iloc[0,0][5:7])

# Declare start year
start_year = 2000

# Development purpose only
row_length = len(rent_data)
print(row_length)
# rent_data.iloc[row_length - 1,0]
# Out:
# 433

# %%
# Print First Year Entry - Development purpose only
print(csv_year)
# Out:
# 1982

# %%
# Print First Month Entry - Development purpose only
print(csv_month)
# Out:
# 11

# %%
# Create Monthly Series Append in new DataFrame
row_count_convert = (start_year - (csv_year+1)) * 12 - csv_month + 13

# df co-ordinates = begin period : row_length - 1
print(row_count_convert)
# Out:
# 206

# %%
# Create DataFrame of Gender / Gender Count / Percentage of Total Players for each Gender
rent_data_convert = pd.DataFrame({"Date": rent_data.iloc[row_count_convert:row_length,0],
                                  "Index": rent_data.iloc[row_count_convert:row_length,1].astype(float)                             
                                 })


rent_data_convert.reset_index(drop=True,inplace=True)

rent_data_convert_final = pd.DataFrame({"Date": rent_data_convert["Date"], 
                                        "Seattle Index": rent_data_convert["Index"].astype(float),
                                        "National Index": rent_data_formatted["Index"].astype(float)
                                       }) 

rent_data_convert_final.head()

# rent_data_convert.head()
# Out:
#          Date  Seattle Index  National Index
# 0  2000-01-01          205.9           181.1
# 1  2000-02-01          206.2           181.5
# 2  2000-03-01          206.8           182.0
# 3  2000-04-01          208.0           182.3
# 4  2000-05-01          209.2           182.7

# %%
# Development Purposes Only - Show Index Factor of Start Date and last Date
print(index_factor)
# Out:
# 1.7888901159580344

# %%
# Development Purposes Only
print(len(rent_data_convert))
# Out:
# 227

# %%
# Development Purposes Only - Check Row Count
checksum = row_length + 1 - row_count_convert

print(checksum)
# Out:
# 228

# %%
rent_data_convert.head(len(rent_data_convert))
# Out:
#             Date    Index
# 1021  2000-01-01  181.100
# 1022  2000-02-01  181.500
# 1023  2000-03-01  182.000
# 1024  2000-04-01  182.300
# 1025  2000-05-01  182.700
# 1026  2000-06-01  183.200
# 1027  2000-07-01  183.900
# 1028  2000-08-01  184.600
# 1029  2000-09-01  185.300
# 1030  2000-10-01  186.100
# 1031  2000-11-01  186.800
# 1032  2000-12-01  187.600
# 1033  2001-01-01  188.200
# 1034  2001-02-01  188.900
# 1035  2001-03-01  189.600
# 1036  2001-04-01  190.200
# 1037  2001-05-01  191.000
# 1038  2001-06-01  191.600
# 1039  2001-07-01  192.300
# 1040  2001-08-01  193.100
# 1041  2001-09-01  193.900
# 1042  2001-10-01  194.700
# 1043  2001-11-01  195.500
# 1044  2001-12-01  196.400
# 1045  2002-01-01  197.000
# 1046  2002-02-01  197.700
# 1047  2002-03-01  198.200
# 1048  2002-04-01  198.500
# 1049  2002-05-01  198.800
# 1050  2002-06-01  199.300
# ...          ...      ...
# 1218  2016-06-01  295.902
# 1219  2016-07-01  296.862
# 1220  2016-08-01  297.916
# 1221  2016-09-01  298.962
# 1222  2016-10-01  300.400
# 1223  2016-11-01  301.587
# 1224  2016-12-01  302.735
# 1225  2017-01-01  303.467
# 1226  2017-02-01  304.211
# 1227  2017-03-01  304.868
# 1228  2017-04-01  305.477
# 1229  2017-05-01  306.379
# 1230  2017-06-01  307.314
# 1231  2017-07-01  308.173
# 1232  2017-08-01  309.479
# 1233  2017-09-01  310.268
# 1234  2017-10-01  311.501
# 1235  2017-11-01  312.670
# 1236  2017-12-01  313.904
# 1237  2018-01-01  314.788
# 1238  2018-02-01  315.277
# 1239  2018-03-01  315.883
# 1240  2018-04-01  316.763
# 1241  2018-05-01  317.490
# 1242  2018-06-01  318.318
# 1243  2018-07-01  319.351
# 1244  2018-08-01  320.651
# 1245  2018-09-01  321.533
# 1246  2018-10-01  322.628
# 1247  2018-11-01  323.968
#
# [227 rows x 2 columns]

# %%
# New Unformatted DataFrame CSV Filename:
csv_output_name = input("Enter csv file output name: ")

# %%
# Export DataFrame to CSV
rent_data_convert.to_csv(path_or_buf=csv_output_name,index=False)

# %%
# New Combined DataFrame CSV Filename:
csv_final_output_name = input("Enter final csv file output name: ")

# %%
# Export DataFrame to CSV
rent_data_convert_final.to_csv(path_or_buf=csv_final_output_name,index=False)

# %%
# Create Line Plot
rent_data_convert_final.plot(kind="line", x='Date', y=['Seattle Index','National Index'], grid=True, figsize=(10,5),
                             title="Seattle vs. National Rent Index: 1982 = 100")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1128.7499831803145">
