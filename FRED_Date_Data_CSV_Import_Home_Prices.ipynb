# %%
# %matplotlib notebook

# %%
# This code will parse a two column [Date / Data] CSV file from FRED by Defined Period

# Import Dependencies
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt

# %%
# load Seattle CSV File

# loop_trigger = 'y'

# while loop trigger == 'y':

# File name: S&P_CS_Housing_US.csv
file_df = input("Enter file to load: ")

# Read CSV File and store into Pandas data frame
rent_data = pd.read_csv(file_df)
# Out:
# Enter file to load: S&P_CS_Housing_US.csv

# %%
# Append national Formatted CSV File

# File name: Seattle_CS_Formatted.csv
formatted_file_df = input("Enter formatted file to load: ")

# Read CSV File and store into Pandas data frame
rent_data_formatted = pd.read_csv(formatted_file_df)
# Out:
# Enter formatted file to load: Seattle_CS_Formatted.csv

# %%
# Development Purposes Only - Check Row Count
formatted_row_count = len(rent_data_formatted)
# rent_data_formatted.set_index('Date')
# rent_data_formatted_bin = pd.cut(rent_data_formatted['Index'].astype(float),1)
# formatted_series = pd.Series(rent_data_formatted.iloc[0:formatted_row_count,1])


print(formatted_row_count)
# Out:
# 226

# %%
# print(formatted_series)

rent_data_formatted.head()
# Out:
#          Date      Index
# 0  2000-01-01  100.00000
# 1  2000-02-01  100.48036
# 2  2000-03-01  102.23654
# 3  2000-04-01  103.45586
# 4  2000-05-01  104.78048

# %%
print(rent_data_formatted.iloc[0:formatted_row_count,1])
# Out:
# 0      100.000000
# 1      100.480360
# 2      102.236540
# 3      103.455860
# 4      104.780480
# 5      105.279440
# 6      105.816260
# 7      105.877200
# 8      106.101280
# 9      106.083240
# 10     106.332360
# 11     106.732490
# 12     106.699010
# 13     106.717780
# 14     107.408360
# 15     108.971320
# 16     109.758230
# 17     110.556320
# 18     110.836360
# 19     111.231910
# 20     111.716590
# 21     111.935720
# 22     111.974870
# 23     111.581730
# 24     111.794430
# 25     112.067780
# 26     112.740160
# 27     113.397990
# 28     114.176950
# 29     114.841870
#           ...
# 196    199.818253
# 197    202.545709
# 198    203.704225
# 199    204.554996
# 200    204.545509
# 201    204.806290
# 202    205.126040
# 203    206.284227
# 204    207.499843
# 205    211.317573
# 206    216.812942
# 207    222.484383
# 208    226.425470
# 209    229.642600
# 210    231.147954
# 211    231.565192
# 212    230.932073
# 213    230.765373
# 214    231.189486
# ...

# %%
# Display CSV
rent_data.head(10)
# Out:
#          DATE  CSUSHPINSA
# 0  1987-01-01      63.753
# 1  1987-02-01      64.153
# 2  1987-03-01      64.490
# 3  1987-04-01      64.995
# 4  1987-05-01      65.570
# 5  1987-06-01      66.239
# 6  1987-07-01      66.801
# 7  1987-08-01      67.282
# 8  1987-09-01      67.637
# 9  1987-10-01      67.917

# %%
# Date dependency calculation - Start Date
print(rent_data.iloc[0,0])
# Out:
# 1987-01-01

# %%
# Development Purposes Only - Show Type of Data In CSV
type(rent_data.iloc[0,0])
# Out:
# str

# %%
# Convert dataseries to years/months as Integers
csv_year = int(rent_data.iloc[0,0][0:4])
csv_month = int(rent_data.iloc[0,0][5:7])

# Declare start year
start_year = 2000

# Development purpose only
row_length = len(rent_data)
print(row_length)
# rent_data.iloc[row_length - 1,0]
# Out:
# 382

# %%
# Print First Year Entry - Development purpose only
print(csv_year)
# Out:
# 1987

# %%
# Print First Month Entry - Development purpose only
print(csv_month)
# Out:
# 1

# %%
# Create Monthly Series Append in new DataFrame
row_count_convert = (start_year - (csv_year+1)) * 12 - csv_month + 13

# df co-ordinates = begin period : row_length - 1
print(row_count_convert)
# Out:
# 156

# %%
# Create DataFrame of Gender / Gender Count / Percentage of Total Players for each Gender
rent_data_convert = pd.DataFrame({"Date": rent_data.iloc[row_count_convert:row_length,0],
                                  "Index": rent_data.iloc[row_count_convert:row_length,1].astype(float)                             
                                 })


rent_data_convert.reset_index(drop=True,inplace=True)

rent_data_convert_final = pd.DataFrame({"Date": rent_data_convert["Date"], 
                                        "Seattle Index": rent_data_convert["Index"].astype(float),
                                        "National Index": rent_data_formatted["Index"].astype(float)
                                       }) 

rent_data_convert_final.head()

# rent_data_convert.head()
# Out:
#          Date  Seattle Index  National Index
# 0  2000-01-01        100.000       100.00000
# 1  2000-02-01        100.570       100.48036
# 2  2000-03-01        101.465       102.23654
# 3  2000-04-01        102.540       103.45586
# 4  2000-05-01        103.702       104.78048

# %%
# Development Purposes Only - Show Index Factor of Start Date and last Date
print(index_factor)
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-34-beea94a55140> in <module>
#       1 # Development Purposes Only - Show Index Factor of Start Date and last Date
# ----> 2 print(index_factor)
#
# NameError: name 'index_factor' is not defined

# %%
# Development Purposes Only
print(len(rent_data_convert))

# %%
# Development Purposes Only - Check Row Count
checksum = row_length + 1 - row_count_convert

print(checksum)
# Out:
# 227

# %%
rent_data_convert.head(len(rent_data_convert))
# Out:
#            Date    Index
# 0    2000-01-01  100.000
# 1    2000-02-01  100.570
# 2    2000-03-01  101.465
# 3    2000-04-01  102.540
# 4    2000-05-01  103.702
# 5    2000-06-01  104.855
# 6    2000-07-01  105.721
# 7    2000-08-01  106.521
# 8    2000-09-01  107.135
# 9    2000-10-01  107.728
# 10   2000-11-01  108.290
# 11   2000-12-01  108.791
# 12   2001-01-01  109.214
# 13   2001-02-01  109.642
# 14   2001-03-01  110.394
# 15   2001-04-01  111.247
# 16   2001-05-01  112.203
# 17   2001-06-01  113.273
# 18   2001-07-01  114.229
# 19   2001-08-01  114.990
# 20   2001-09-01  115.466
# 21   2001-10-01  115.682
# 22   2001-11-01  115.838
# 23   2001-12-01  116.055
# 24   2002-01-01  116.437
# 25   2002-02-01  116.917
# 26   2002-03-01  117.931
# 27   2002-04-01  119.211
# 28   2002-05-01  120.790
# 29   2002-06-01  122.334
# ..          ...      ...
# 196  2016-05-01  180.413
# 197  2016-06-01  182.002
# 198  2016-07-01  183.123
# 199  2016-08-01  183.773
# 200  2016-09-01  184.070
# ...

# %%
# New Unformatted DataFrame CSV Filename:
# csv_output_name = input("Enter csv file output name: ")
# Out:
# Enter csv file output name: Seattle_CS_Formatted.csv

# %%
# Export DataFrame to CSV
# rent_data_convert.to_csv(path_or_buf=csv_output_name,index=False)

# %%
# New Combined DataFrame CSV Filename:
csv_final_output_name = input("Enter final csv file output name: ")
# Out:
# Enter final csv file output name: Seattle_CS_National_Comparison.csv

# %%
# Export DataFrame to CSV
rent_data_convert_final.to_csv(path_or_buf=csv_final_output_name,index=False)

# %%
# Create Line Plot
rent_data_convert_final.plot(kind="line", x='Date', y=['Seattle Index','National Index'], grid=True, figsize=(10,5),
                             title="Seattle vs. National Housing Price Index: 1982 = 100")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
